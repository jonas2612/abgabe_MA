# %%
import pandas as pd
import seaborn as sns

# %%
ds = ['exvito', 'gastrulation', 'invito']
genes = ['10k', 'all']
metric = ['ari', 'ASW', 'batch_ASW', 'cLISI', 'graph_connectivity', 'iLISI', 'iso_ASW', 'nmi', 'pcr', 'iso_F1']

# %%
data = []
for d in ds:
    for m in metric:
        tmp = pd.read_csv(f'{d}_{m}_unintegrated.csv')
        tmp['integrated'] = 'unintegrated'
        tmp['n_genes'] = '10k_genes'
        if m =='ari':
            tmp['metric'] = 'ari_unintegrated'
        elif m=='iso_F1':
            tmp['metric'] = 'iso_F1_unintegrated'
        data.append(tmp)
        tmp = pd.read_csv(f'{d}_{m}_unintegrated.csv')
        tmp['integrated'] = 'unintegrated'
        tmp['n_genes'] = 'all_genes'
        if m =='ari':
            tmp['metric'] = 'ari_unintegrated'
        elif m=='iso_F1':
            tmp['metric'] = 'iso_F1_unintegrated'
        data.append(tmp)
        for g in genes:
            tmp = pd.read_csv(f'{d}_{g}_genes_{m}_integrated.csv')
            tmp['integrated'] = 'integrated'
            data.append(tmp)
            tmp = pd.read_csv(f'{d}_{g}_genes_traject_conservation.csv')
            tmp['integrated'] = 'integrated'
            data.append(tmp)
data = pd.concat(data)
data
# Out:
#     Unnamed: 0 dataset    n_genes                metric     value  \
# 0            0  exvito  10k_genes      ari_unintegrated  0.577447
# 0            0  exvito  all_genes      ari_unintegrated  0.577447
# 0            0  exvito  10k_genes        ari_integrated  0.562810
# 0            0  exvito  10k_genes  traject_conservation  0.850516
# 0            0  exvito  all_genes        ari_integrated  0.550461
# ..         ...     ...        ...                   ...       ...
# 0            0  invito  all_genes   iso_F1_unintegrated  0.748879
# 0            0  invito  10k_genes     iso_F1_integrated  0.746622
# 0            0  invito  10k_genes  traject_conservation  0.669299
# 0            0  invito  all_genes     iso_F1_integrated  0.746130
# 0            0  invito  all_genes  traject_conservation  0.664702
#
#       integrated
# 0   unintegrated
# 0   unintegrated
# 0     integrated
# 0     integrated
# 0     integrated
# ..           ...
# 0   unintegrated
# 0     integrated
# ...

# %%
invitro = data[data.dataset=='invito']
exvitro = data[data.dataset=='exvito']
gastrulation = data[data.dataset=='gastrulation']

# %% [markdown]
# # Invitro

# %%
fig = sns.pointplot(invitro[[x in ['ari_integrated', 'ari_unintegrated'] for x in invitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(invitro[[x in ['nmi_integrated', 'nmi_unintegrated'] for x in invitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(invitro[[x in ['ASW_integrated', 'ASW_unintegrated'] for x in invitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(invitro[[x in ['batch_ASW_integrated', 'batch_ASW_unintegrated'] for x in invitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(invitro[[x in ['cLISI_integrated', 'cLISI_unintegrated'] for x in invitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(invitro[[x in ['iLISI_integrated', 'iLISI_unintegrated'] for x in invitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(invitro[[x in ['iso_ASW_integrated', 'iso_ASW_unintegrated'] for x in invitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(invitro[[x in ['iso_F1_integrated', 'iso_F1_unintegrated'] for x in invitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(invitro[[x in ['graph_conn_integrated', 'graph_conn_unintegrated'] for x in invitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(invitro[[x in ['pcr_integrated', 'pcr_unintegrated'] for x in invitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
sns.pointplot(invitro[[x in ['traject_conservation'] for x in invitro['metric']]], y='value', x='n_genes', linestyles="none")
# Out:
# <Axes: xlabel='n_genes', ylabel='value'>

# %% [markdown]
# # Exvitro

# %%
fig = sns.pointplot(exvitro[[x in ['ari_integrated', 'ari_unintegrated'] for x in exvitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(exvitro[[x in ['nmi_integrated', 'nmi_unintegrated'] for x in exvitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(exvitro[[x in ['ASW_integrated', 'ASW_unintegrated'] for x in exvitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(exvitro[[x in ['batch_ASW_integrated', 'batch_ASW_unintegrated'] for x in exvitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(exvitro[[x in ['cLISI_integrated', 'cLISI_unintegrated'] for x in exvitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(exvitro[[x in ['iLISI_integrated', 'iLISI_unintegrated'] for x in exvitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(exvitro[[x in ['iso_ASW_integrated', 'iso_ASW_unintegrated'] for x in exvitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(exvitro[[x in ['iso_F1_integrated', 'iso_F1_unintegrated'] for x in exvitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(exvitro[[x in ['graph_conn_integrated', 'graph_conn_unintegrated'] for x in exvitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(exvitro[[x in ['pcr_integrated', 'pcr_unintegrated'] for x in exvitro['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(exvitro[[x in ['traject_conservation'] for x in exvitro['metric']]], y='value', x='n_genes', linestyles="none")

# %% [markdown]
# # Gastrulation

# %%
fig = sns.pointplot(gastrulation[[x in ['ari_integrated', 'ari_unintegrated'] for x in gastrulation['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(gastrulation[[x in ['nmi_integrated', 'nmi_unintegrated'] for x in gastrulation['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(gastrulation[[x in ['ASW_integrated', 'ASW_unintegrated'] for x in gastrulation['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(gastrulation[[x in ['batch_ASW_integrated', 'batch_ASW_unintegrated'] for x in gastrulation['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(gastrulation[[x in ['cLISI_integrated', 'cLISI_unintegrated'] for x in gastrulation['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(gastrulation[[x in ['iLISI_integrated', 'iLISI_unintegrated'] for x in gastrulation['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(gastrulation[[x in ['iso_ASW_integrated', 'iso_ASW_unintegrated'] for x in gastrulation['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(gastrulation[[x in ['iso_F1_integrated', 'iso_F1_unintegrated'] for x in gastrulation['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(gastrulation[[x in ['graph_conn_integrated', 'graph_conn_unintegrated'] for x in gastrulation['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(gastrulation[[x in ['pcr_integrated', 'pcr_unintegrated'] for x in gastrulation['metric']]], y='value', x='n_genes', hue='integrated', linestyles="none")
sns.move_legend(fig, "upper left", bbox_to_anchor=(1, 1))

# %%
fig = sns.pointplot(invitro[[x in ['traject_conservation'] for x in gastrulation['metric']]], y='value', x='n_genes', linestyles="none")
