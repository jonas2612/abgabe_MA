# %%
import scanpy as sc

# %%
adata = sc.read_h5ad('/home/icb/jonas.flor/gastrulation_atlas/scvi/training/1M/10k_genes/2/2048/integrated_adata.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 1000000 × 10000
#     obs: 'cell_id', 'keep', 'day', 'embryo_id', 'experimental_batch', 'batch', 'cell_cluster', 'celltype', 'cellcluster_moscot', '_scvi_batch', '_scvi_labels', 'dpt_pseudotime'
#     uns: 'diffmap_evals', 'iroot', 'log1p', 'neighbors'
#     obsm: 'X_diffmap', 'X_emb'
#     obsp: 'connectivities', 'distances'

# %%
sc.tl.umap(adata)

# %%
sc.pl.umap(adata, color='cellcluster_moscot', save='_atlas_integrated_1M_10k_2_2048_cellcluster_m.png')
# Out:
# WARNING: saving figure to file figures/umap_atlas_integrated_1M_10k_2_2048_cellcluster_m.png
# /home/icb/jonas.flor/mambaforge/envs/scvi/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(

# %%
sc.pl.umap(adata, color='day', save='_atlas_integrated_1M_10k_2_2048_day.png')
# Out:
# WARNING: saving figure to file figures/umap_atlas_integrated_1M_10k_2_2048_day.png

# %%
sc.pl.umap(adata, color='embryo_id', save='_atlas_integrated_1M_10k_2_2048_embryos.png')
# Out:
# /home/icb/jonas.flor/mambaforge/envs/scvi/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file figures/umap_atlas_integrated_1M_10k_2_2048_embryos.png

# %%
adata = sc.read_h5ad('/home/icb/jonas.flor/gastrulation_atlas/scvi/training/1M/all_genes/2/2048/integrated_adata.h5ad')
sc.tl.umap(adata)
sc.pl.umap(adata, color='cellcluster_moscot', save='_atlas_integrated_1M_all_2_2048_cellcluster_m.png')
sc.pl.umap(adata, color='day', save='_atlas_integrated_1M_all_2_2048_day.png')
sc.pl.umap(adata, color='embryo_id', save='_atlas_integrated_1M_all_2_2048_embryos.png')
# Out:
# WARNING: saving figure to file figures/umap_atlas_integrated_1M_all_2_2048_cellcluster_m.png
# /home/icb/jonas.flor/mambaforge/envs/scvi/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file figures/umap_atlas_integrated_1M_all_2_2048_day.png
# /home/icb/jonas.flor/mambaforge/envs/scvi/lib/python3.11/site-packages/scanpy/plotting/_tools/scatterplots.py:391: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   cax = scatter(
# WARNING: saving figure to file figures/umap_atlas_integrated_1M_all_2_2048_embryos.png

# %%
adata = sc.read_h5ad('/lustre/groups/ml01/workspace/monge_velo/data/mouse_gastrulation_atlas/training/adata_1M.h5ad')
adata
# Out:
# AnnData object with n_obs × n_vars = 1000000 × 24552
#     obs: 'cell_id', 'keep', 'day', 'embryo_id', 'experimental_batch', 'batch', 'cell_cluster', 'celltype', 'cellcluster_moscot'
#     var: 'gene_type', 'celltype', 'chr'
#     uns: 'neighbors'
#     obsm: 'X_pca'
#     obsp: 'connectivities', 'distances'

# %%
sc.tl.umap(adata)
sc.pl.umap(adata, color='cellcluster_moscot', save='_atlas_integrated_1M_all_2_2048_cellcluster_m.png')
sc.pl.umap(adata, color='day', save='_atlas_integrated_1M_all_2_2048_day.png')
sc.pl.umap(adata, color='embryo_id', save='_atlas_integrated_1M_all_2_2048_embryos.png')
