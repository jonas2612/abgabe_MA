# %%
import pandas as pd
import scanpy as sc

# %%
adata = sc.read("/lustre/groups/ml01/workspace/monge_velo/data/mouse_gastrulation_atlas_full_celltypes.h5ad")

# %%
Notochord = ['Notochord', 'Ciliated nodal cells']
Gut = ['Gut', 'Foregut epithelial cells', 'Pancreatic islets', 'Pancreatic acinar cells', 'Biliary epithelial cells']
Intermediate_mesoderm_and_kidney = ['Anterior intermediate mesoderm', 
                                    'Posterior intermediate mesoderm', 'Ureteric bud', 'Metanephric mesenchyme',
                                    'Collecting duct principal cells', 'Nephron progenitors',
                                    'Distal convoluted tubule', 'Ascending loop of Henle',
                                    'Podocytes', 'Proximal tubule cells', 'Connecting tubule', 
                                    'Collecting duct intercalated cells'
                                   ]
Eye_and_other = ['Naive retinal progenitor cells', 'Retinal progenitor cells', 'Ciliary margin cells', 
                 'Suprachiasmatic nucleus', 'Bipolar precursor cells', 'Photoreceptor precursor cells', 
                 'Rod precursor cells', 'Cone precursor cells'
                ]
Epithelial_cells = ['Placodal area', 'Olfactory epithelial cells', 'Olfactory bulb cells', 'Thyroid gland cells',
                    'Olfactory pit cells', 'Pituitary/Pineal gland progenitors', 'Thymic epithelial cells',
                    'Basal keratinocytes', 'Apical ectodermal ridge', 'Granular keratinocytes',
                    'Lens epithelial cells', 'Branchial arch epithelium', 'Conjunctival goblet cells',
                    'Corneal epithelial cells', 'Bladder urothelial cells', 'Parathyroid epithelial cells',
                    'Tooth junctional epithelium', 'Dental epithelial cells', 'Amniotic ectoderm', 
                    'Pre-epidermal keratinocytes', 'Otic epithelial cells'
                   ]
Glands = ['Nonsensory cochlear epithelium', 'Pineal gland', 'Pituitary gland cells', 'Cochlear hair cells']
Mesoderm = ['Chondrocytes (Atp1a2+)', 'Chondrocytes (Otor+)', 'Dermatome', 'Dermomyotome', 'Early chondrocytes',
            'Facial mesenchyme', 'Fibroblasts', 'Lateral plate and intermediate mesoderm', 
            'Limb mesenchyme progenitors', 'Mesodermal progenitors (Tbx6+)', 'Pre-osteoblasts (Sp7+)', 'Sclerotome'
           ]
Cardiocytes = ['Atrial cardiomyocytes', 'First heart field', 'Second heart field', 'Ventricular cardiomyocytes']
Aidpocytes = ['Adipocyte cells (Cyp2e1+)', 'Adipocyte progenitor cells', 'Brown adipocyte cells']
Muscle_cells = ['Muscle progenitor cells', 'Muscle progenitor cells (Prdm1+)', 'Myoblasts', 'Myofibroblasts',
                'Myotubes'
               ]
Testis_and_adrenal = ['Adrenocortical cells', 'Leydig cells']
Neural_crest_PNS_neurons = ['Dorsal root ganglion neurons', 'Enteric neurons', 'Neural crest (PNS neurons)',
                            'Otic sensory neurons', 'Parasympathetic neurons', 'Sympathetic neurons'
                           ]
Neural_crest_PNS_glia = ['Melanocyte cells', 'Myelinating Schwann cells', 'Myelinating Schwann cells (Tgfb2+)',
                         'Neural crest (PNS glia)', 'Olfactory ensheathing cells', 'Satellite glial cells'
                        ]
Olfactory_sensory_neurons = ['Corticofugal neurons', 'Olfactory sensory neurons']
Neuroectoderm_and_glia = ['Anterior floor plate', 'Anterior roof plate', 'Astrocytes', 'Diencephalon',
                          'Cerebellum-related cells', 'Dorsal telencephalon', 'Eye field', 'Floorplate and p3 domain',
                          'Hindbrain', 'Hypothalamus', 'Hypothalamus (Sim1+)', 'Midbrain', 
                          'Midbrain-hindbrain boundary', 'Multiciliated ependymal cells', 
                          'NMPs and spinal cord progenitors', 'Posterior roof plate', 'Retinal pigment cells', 
                          'Spinal cord/r7/r8', 'Telencephalon'
                         ]
CNS_neurons = ['Amacrine cells', 'Amacrine/Horizontal precursor cells', 'Cajal-Retzius cells', 
               'Cerebellar Purkinje cells', 'Cholinergic amacrine cells', 'Cranial motor neurons', 
               'GABAergic cortical interneurons', 'GABAergic neurons', 'Glutamatergic neurons', 'Horizontal cells',
               'Neural progenitor cells (Neurod1+)', 'Neural progenitor cells (Ror1+)', 'Neurons (Slc17a8+)',
               'PV-containing retinal ganglion cells', 'Retinal ganglion cells', 'Spinal cord dorsal progenitors', 
               'Spinal cord motor neurons', 'Spinal cord ventral progenitors', 'Thalamic neuronal precursors'
              ]
Ependymal_cells = ['Choroid plexus', 'Ependymal cells']
Olidendrocytes = ['Committed oligodendrocyte precursors', 'Oligodendrocyte progenitor cells']
Intermediate_neuronal_progenitors = ['Cortical Interneurons (Prox1+)', 'Deep-layer neurons', 
                                     'Intermediate neuronal progenitors', 'Subplate neurons', 'Upper-layer neurons'
                                    ]
Endothelium = ['Arterial endothelial cells', 'Brain capillary endothelial cells', 'Brain pericytes', 
               'Endocardial cells', 'Endothelium', 'Glomerular endothelial cells', 'Hematoendothelial progenitors',
               'Liver sinusoidal endothelial cells', 'Lymphatic vessel endothelial cells',
               'Microvascular endothelial cells', 'Pericytes', 'Venous and capillary endothelial cells'
              ]
Definitive_erythroid = ['Definitive early erythroblasts (CD36-)', 'Definitive erythroblasts (CD36+)']
B_cells = ['B cell progenitors', 'B cells']
Hepatocytes = ['Hepatocytes']
Intestine = ['Intestinal enteroendocrine cells', 'Intestinal goblet cells', 'Midgut/Hindgut epithelial cells']
Lung_and_airways = ['Airway club cells', 'Airway goblet cells', 'Alveolar Type 1 cells', 'Alveolar Type 2 cells',
                    'Lung cells (Eln+)', 'Lung progenitor cells'
                   ]
Mast_cells = ['Mast cells', 'Mast cells (P2rx7+)']
Megakaryocytes = ['Megakaryocytes']
Primitive_erythroid = ['Primitive erythroid cells']
T_cells = ['Activated T cells', 'Natural killer cells', 'Regulatory T cells', 'T cells']
White_blood_cells = ['Adipose tissue macrophages', 'Border-associated macrophages', 
                     'Border-associated macrophages (Cd74+)', 'Border-associated macrophages (Ms4a8a+)',
                     'Conventional dendritic cells', 'Granulocytes', 'Hematopoietic stem cells (Cd34+)',
                     'Hematopoietic stem cells (Mpo+)', 'Kupffer cells', 'Microglia', 'Monocytes', 
                     'Monocytic myeloid-derived suppressor cells', 'Osteoclasts', 
                     'PMN myeloid-derived suppressor cells', 'Plasmacytoid dendritic cells'
                    ]
Extraembryonic_visceral_endoderm = ['Extraembryonic visceral endoderm']
Primordial_germ_cells = ['Primordial germ cells']

# %%
liste1 = ['Notochord','Gut','Intermediate_mesoderm_and_kidney','Eye_and_other','Epithelial_cells','Glands','Mesoderm','Cardiocytes','Aidpocytes','Muscle_cells','Testis_and_adrenal','Neural_crest_PNS_neurons','Neural_crest_PNS_glia','Olfactory_sensory_neurons','Neuroectoderm_and_glia','CNS_neurons','Ependymal_cells','Olidendrocytes','Intermediate_neuronal_progenitors','Endothelium','Definitive_erythroid','B_cells','Hepatocytes','Intestine','Lung_and_airways','Mast_cells','Megakaryocytes','Primitive_erythroid','T_cells','White_blood_cells','Extraembryonic_visceral_endoderm','Primordial_germ_cells']
liste2 = [Notochord,Gut,Intermediate_mesoderm_and_kidney,Eye_and_other,Epithelial_cells,Glands,Mesoderm,Cardiocytes,Aidpocytes,Muscle_cells,Testis_and_adrenal,Neural_crest_PNS_neurons,Neural_crest_PNS_glia,Olfactory_sensory_neurons,Neuroectoderm_and_glia,CNS_neurons,Ependymal_cells,Olidendrocytes,Intermediate_neuronal_progenitors,Endothelium,Definitive_erythroid,B_cells,Hepatocytes,Intestine,Lung_and_airways,Mast_cells,Megakaryocytes,Primitive_erythroid,T_cells,White_blood_cells,Extraembryonic_visceral_endoderm,Primordial_germ_cells]

# %%
dic = {}

for i in range(len(liste1)):
    for celltype in liste2[i]:
        dic[celltype] = liste1[i]
        
dic
# Out:
# {'Notochord': 'Notochord',
#  'Ciliated nodal cells': 'Notochord',
#  'Gut': 'Gut',
#  'Foregut epithelial cells': 'Gut',
#  'Pancreatic islets': 'Gut',
#  'Pancreatic acinar cells': 'Gut',
#  'Biliary epithelial cells': 'Gut',
#  'Anterior intermediate mesoderm': 'Intermediate_mesoderm_and_kidney',
#  'Posterior intermediate mesoderm': 'Intermediate_mesoderm_and_kidney',
#  'Ureteric bud': 'Intermediate_mesoderm_and_kidney',
#  'Metanephric mesenchyme': 'Intermediate_mesoderm_and_kidney',
#  'Collecting duct principal cells': 'Intermediate_mesoderm_and_kidney',
#  'Nephron progenitors': 'Intermediate_mesoderm_and_kidney',
#  'Distal convoluted tubule': 'Intermediate_mesoderm_and_kidney',
#  'Ascending loop of Henle': 'Intermediate_mesoderm_and_kidney',
#  'Podocytes': 'Intermediate_mesoderm_and_kidney',
#  'Proximal tubule cells': 'Intermediate_mesoderm_and_kidney',
#  'Connecting tubule': 'Intermediate_mesoderm_and_kidney',
#  'Collecting duct intercalated cells': 'Intermediate_mesoderm_and_kidney',
#  'Naive retinal progenitor cells': 'Eye_and_other',
#  'Retinal progenitor cells': 'Eye_and_other',
#  'Ciliary margin cells': 'Eye_and_other',
#  'Suprachiasmatic nucleus': 'Eye_and_other',
#  'Bipolar precursor cells': 'Eye_and_other',
#  'Photoreceptor precursor cells': 'Eye_and_other',
#  'Rod precursor cells': 'Eye_and_other',
#  'Cone precursor cells': 'Eye_and_other',
#  'Placodal area': 'Epithelial_cells',
#  'Olfactory epithelial cells': 'Epithelial_cells',
#  'Olfactory bulb cells': 'Epithelial_cells',
#  'Thyroid gland cells': 'Epithelial_cells',
#  'Olfactory pit cells': 'Epithelial_cells',
#  'Pituitary/Pineal gland progenitors': 'Epithelial_cells',
#  'Thymic epithelial cells': 'Epithelial_cells',
#  'Basal keratinocytes': 'Epithelial_cells',
#  'Apical ectodermal ridge': 'Epithelial_cells',
#  'Granular keratinocytes': 'Epithelial_cells',
#  'Lens epithelial cells': 'Epithelial_cells',
#  'Branchial arch epithelium': 'Epithelial_cells',
#  'Conjunctival goblet cells': 'Epithelial_cells',
#  'Corneal epithelial cells': 'Epithelial_cells',
#  'Bladder urothelial cells': 'Epithelial_cells',
#  'Parathyroid epithelial cells': 'Epithelial_cells',
#  'Tooth junctional epithelium': 'Epithelial_cells',
#  'Dental epithelial cells': 'Epithelial_cells',
#  'Amniotic ectoderm': 'Epithelial_cells',
#  'Pre-epidermal keratinocytes': 'Epithelial_cells',
#  'Otic epithelial cells': 'Epithelial_cells',
#  'Nonsensory cochlear epithelium': 'Glands',
#  'Pineal gland': 'Glands',
#  'Pituitary gland cells': 'Glands',
#  'Cochlear hair cells': 'Glands',
#  'Chondrocytes (Atp1a2+)': 'Mesoderm',
#  'Chondrocytes (Otor+)': 'Mesoderm',
#  'Dermatome': 'Mesoderm',
#  'Dermomyotome': 'Mesoderm',
#  'Early chondrocytes': 'Mesoderm',
#  'Facial mesenchyme': 'Mesoderm',
#  'Fibroblasts': 'Mesoderm',
#  'Lateral plate and intermediate mesoderm': 'Mesoderm',
#  'Limb mesenchyme progenitors': 'Mesoderm',
#  'Mesodermal progenitors (Tbx6+)': 'Mesoderm',
#  'Pre-osteoblasts (Sp7+)': 'Mesoderm',
#  'Sclerotome': 'Mesoderm',
#  'Atrial cardiomyocytes': 'Cardiocytes',
#  'First heart field': 'Cardiocytes',
#  'Second heart field': 'Cardiocytes',
#  'Ventricular cardiomyocytes': 'Cardiocytes',
#  'Adipocyte cells (Cyp2e1+)': 'Aidpocytes',
#  'Adipocyte progenitor cells': 'Aidpocytes',
#  'Brown adipocyte cells': 'Aidpocytes',
#  'Muscle progenitor cells': 'Muscle_cells',
#  'Muscle progenitor cells (Prdm1+)': 'Muscle_cells',
#  'Myoblasts': 'Muscle_cells',
#  'Myofibroblasts': 'Muscle_cells',
#  'Myotubes': 'Muscle_cells',
#  'Adrenocortical cells': 'Testis_and_adrenal',
#  'Leydig cells': 'Testis_and_adrenal',
#  'Dorsal root ganglion neurons': 'Neural_crest_PNS_neurons',
#  'Enteric neurons': 'Neural_crest_PNS_neurons',
#  'Neural crest (PNS neurons)': 'Neural_crest_PNS_neurons',
#  'Otic sensory neurons': 'Neural_crest_PNS_neurons',
#  'Parasympathetic neurons': 'Neural_crest_PNS_neurons',
#  'Sympathetic neurons': 'Neural_crest_PNS_neurons',
#  'Melanocyte cells': 'Neural_crest_PNS_glia',
#  'Myelinating Schwann cells': 'Neural_crest_PNS_glia',
#  'Myelinating Schwann cells (Tgfb2+)': 'Neural_crest_PNS_glia',
#  'Neural crest (PNS glia)': 'Neural_crest_PNS_glia',
#  'Olfactory ensheathing cells': 'Neural_crest_PNS_glia',
#  'Satellite glial cells': 'Neural_crest_PNS_glia',
#  'Corticofugal neurons': 'Olfactory_sensory_neurons',
#  'Olfactory sensory neurons': 'Olfactory_sensory_neurons',
#  'Anterior floor plate': 'Neuroectoderm_and_glia',
#  'Anterior roof plate': 'Neuroectoderm_and_glia',
#  'Astrocytes': 'Neuroectoderm_and_glia',
#  'Diencephalon': 'Neuroectoderm_and_glia',
#  'Cerebellum-related cells': 'Neuroectoderm_and_glia',
#  'Dorsal telencephalon': 'Neuroectoderm_and_glia',
#  'Eye field': 'Neuroectoderm_and_glia',
#  'Floorplate and p3 domain': 'Neuroectoderm_and_glia',
#  'Hindbrain': 'Neuroectoderm_and_glia',
#  'Hypothalamus': 'Neuroectoderm_and_glia',
#  'Hypothalamus (Sim1+)': 'Neuroectoderm_and_glia',
#  'Midbrain': 'Neuroectoderm_and_glia',
#  'Midbrain-hindbrain boundary': 'Neuroectoderm_and_glia',
#  'Multiciliated ependymal cells': 'Neuroectoderm_and_glia',
#  'NMPs and spinal cord progenitors': 'Neuroectoderm_and_glia',
#  'Posterior roof plate': 'Neuroectoderm_and_glia',
#  'Retinal pigment cells': 'Neuroectoderm_and_glia',
#  'Spinal cord/r7/r8': 'Neuroectoderm_and_glia',
#  'Telencephalon': 'Neuroectoderm_and_glia',
#  'Amacrine cells': 'CNS_neurons',
#  'Amacrine/Horizontal precursor cells': 'CNS_neurons',
#  'Cajal-Retzius cells': 'CNS_neurons',
#  'Cerebellar Purkinje cells': 'CNS_neurons',
#  'Cholinergic amacrine cells': 'CNS_neurons',
#  'Cranial motor neurons': 'CNS_neurons',
#  'GABAergic cortical interneurons': 'CNS_neurons',
#  'GABAergic neurons': 'CNS_neurons',
#  'Glutamatergic neurons': 'CNS_neurons',
#  'Horizontal cells': 'CNS_neurons',
#  'Neural progenitor cells (Neurod1+)': 'CNS_neurons',
#  'Neural progenitor cells (Ror1+)': 'CNS_neurons',
#  'Neurons (Slc17a8+)': 'CNS_neurons',
#  'PV-containing retinal ganglion cells': 'CNS_neurons',
#  'Retinal ganglion cells': 'CNS_neurons',
#  'Spinal cord dorsal progenitors': 'CNS_neurons',
#  'Spinal cord motor neurons': 'CNS_neurons',
#  'Spinal cord ventral progenitors': 'CNS_neurons',
#  'Thalamic neuronal precursors': 'CNS_neurons',
#  'Choroid plexus': 'Ependymal_cells',
#  'Ependymal cells': 'Ependymal_cells',
#  'Committed oligodendrocyte precursors': 'Olidendrocytes',
#  'Oligodendrocyte progenitor cells': 'Olidendrocytes',
#  'Cortical Interneurons (Prox1+)': 'Intermediate_neuronal_progenitors',
#  'Deep-layer neurons': 'Intermediate_neuronal_progenitors',
#  'Intermediate neuronal progenitors': 'Intermediate_neuronal_progenitors',
#  'Subplate neurons': 'Intermediate_neuronal_progenitors',
#  'Upper-layer neurons': 'Intermediate_neuronal_progenitors',
#  'Arterial endothelial cells': 'Endothelium',
#  'Brain capillary endothelial cells': 'Endothelium',
#  'Brain pericytes': 'Endothelium',
#  'Endocardial cells': 'Endothelium',
#  'Endothelium': 'Endothelium',
#  'Glomerular endothelial cells': 'Endothelium',
#  'Hematoendothelial progenitors': 'Endothelium',
#  'Liver sinusoidal endothelial cells': 'Endothelium',
#  'Lymphatic vessel endothelial cells': 'Endothelium',
#  'Microvascular endothelial cells': 'Endothelium',
#  'Pericytes': 'Endothelium',
#  'Venous and capillary endothelial cells': 'Endothelium',
#  'Definitive early erythroblasts (CD36-)': 'Definitive_erythroid',
#  'Definitive erythroblasts (CD36+)': 'Definitive_erythroid',
#  'B cell progenitors': 'B_cells',
#  'B cells': 'B_cells',
#  'Hepatocytes': 'Hepatocytes',
#  'Intestinal enteroendocrine cells': 'Intestine',
#  'Intestinal goblet cells': 'Intestine',
#  'Midgut/Hindgut epithelial cells': 'Intestine',
#  'Airway club cells': 'Lung_and_airways',
#  'Airway goblet cells': 'Lung_and_airways',
#  'Alveolar Type 1 cells': 'Lung_and_airways',
#  'Alveolar Type 2 cells': 'Lung_and_airways',
#  'Lung cells (Eln+)': 'Lung_and_airways',
#  'Lung progenitor cells': 'Lung_and_airways',
#  'Mast cells': 'Mast_cells',
#  'Mast cells (P2rx7+)': 'Mast_cells',
#  'Megakaryocytes': 'Megakaryocytes',
#  'Primitive erythroid cells': 'Primitive_erythroid',
#  'Activated T cells': 'T_cells',
#  'Natural killer cells': 'T_cells',
#  'Regulatory T cells': 'T_cells',
#  'T cells': 'T_cells',
#  'Adipose tissue macrophages': 'White_blood_cells',
#  'Border-associated macrophages': 'White_blood_cells',
#  'Border-associated macrophages (Cd74+)': 'White_blood_cells',
#  'Border-associated macrophages (Ms4a8a+)': 'White_blood_cells',
#  'Conventional dendritic cells': 'White_blood_cells',
#  'Granulocytes': 'White_blood_cells',
#  'Hematopoietic stem cells (Cd34+)': 'White_blood_cells',
#  'Hematopoietic stem cells (Mpo+)': 'White_blood_cells',
#  'Kupffer cells': 'White_blood_cells',
#  'Microglia': 'White_blood_cells',
#  'Monocytes': 'White_blood_cells',
#  'Monocytic myeloid-derived suppressor cells': 'White_blood_cells',
#  'Osteoclasts': 'White_blood_cells',
#  'PMN myeloid-derived suppressor cells': 'White_blood_cells',
#  'Plasmacytoid dendritic cells': 'White_blood_cells',
#  'Extraembryonic visceral endoderm': 'Extraembryonic_visceral_endoderm',
#  'Primordial germ cells': 'Primordial_germ_cells'}

# %%
adata.obs['annotations_moscot'] = pd.Categorical(
    [dic[celltype] for celltype in adata.obs['celltype']]
)
adata
# Out:
# AnnData object with n_obs × n_vars = 11441407 × 24552
#     obs: 'cell_id', 'keep', 'day', 'embryo_id', 'experimental_batch', 'celltype', 'major_trajectory', 'annotations_moscot'

# %%
adata.write("/lustre/groups/ml01/workspace/monge_velo/data/mouse_gastrulation_atlas_full_celltypes.h5ad")

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 11441407 × 24552
#     obs: 'cell_id', 'keep', 'day', 'embryo_id', 'experimental_batch', 'celltype', 'major_trajectory'
